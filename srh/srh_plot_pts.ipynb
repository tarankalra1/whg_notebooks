# %%
import pandas as pd
import requests
import json
from datetime import datetime
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np

# %%
pwd
# Out:
# '/home/tarandeepk/Desktop/Broad_canal/srh_pp'

# %%
url = 'Output_MISC/Case1_PT4.dat'
df = pd.read_csv(url, delim_whitespace=True)
print(df)
time=df["Time(hours)"]
wse_upstream = df["Water_Elev_ft"]
# Out:
#      Time(hours)        X_ft        Y_ft  Bed_Elev_ft  Water_Elev_ft  \
# 0       0.027778  762453.609  2953734.41    -9.408281       0.570222
# 1       0.055556  762453.609  2953734.41    -9.408281       0.570564
# 2       0.083333  762453.609  2953734.41    -9.408281       0.570616
# 3       0.111111  762453.609  2953734.41    -9.408281       0.570599
# 4       0.138889  762453.609  2953734.41    -9.408281       0.570675
# ..           ...         ...         ...          ...            ...
# 427    11.888889  762453.609  2953734.41    -9.408281       0.512824
# 428    11.916667  762453.609  2953734.41    -9.408281       0.505486
# 429    11.944444  762453.609  2953734.41    -9.408281       0.598097
# 430    11.972222  762453.609  2953734.41    -9.408281       0.685392
# 431    12.000000  762453.609  2953734.41    -9.408281       0.757870
#
#      Water_Depth_ft  Vel_X_ft_p_s  Vel_Y_ft_p_s  Vel_Mag_ft_p_s    Froude  \
# ...

# %%
url_pt2 = 'Output_MISC/Case1_PT2.dat'

df = pd.read_csv(url, delim_whitespace=True)
print(df)
time=df["Time(hours)"]
wse_downstream = df["Water_Elev_ft"]
# Out:
#      Time(hours)        X_ft        Y_ft  Bed_Elev_ft  Water_Elev_ft  \
# 0       0.027778  762453.609  2953734.41    -9.408281       0.570222
# 1       0.055556  762453.609  2953734.41    -9.408281       0.570564
# 2       0.083333  762453.609  2953734.41    -9.408281       0.570616
# 3       0.111111  762453.609  2953734.41    -9.408281       0.570599
# 4       0.138889  762453.609  2953734.41    -9.408281       0.570675
# ..           ...         ...         ...          ...            ...
# 427    11.888889  762453.609  2953734.41    -9.408281       0.512824
# 428    11.916667  762453.609  2953734.41    -9.408281       0.505486
# 429    11.944444  762453.609  2953734.41    -9.408281       0.598097
# 430    11.972222  762453.609  2953734.41    -9.408281       0.685392
# 431    12.000000  762453.609  2953734.41    -9.408281       0.757870
#
#      Water_Depth_ft  Vel_X_ft_p_s  Vel_Y_ft_p_s  Vel_Mag_ft_p_s    Froude  \
# ...

# %%
#plt.figure(figsize=(15, 10))
plt.plot(time, wse_upstream)
plt.plot(time, wse_downstream)
#plt.colorbar(z1_plot)
#plt.colorbar()
#plt.xlim(-100, -60)
#plt.ylim(0,50)
#ax.stock_img()
#ax.coastlines()
#plt.savefig("ADCIRC_run_zoomout.png")
