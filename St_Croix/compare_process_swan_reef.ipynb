# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat

# %%
url_restored = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\1perc_restored_outs.mat'
url_restored = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\65760_CoralReefs_Guam\Swan_Modeling\SwanRuns\NorthGrid\Restored_Reef\1perc\1perc_RestoredReef_outs.mat'
matfile= loadmat(url_restored)
    
print(matfile)
xp=matfile["Xp"]
yp=matfile["Yp"]
Hs_restored_Guam=matfile["Hsig"]
Setup_restored_Guam=matfile["Setup"]
# Out:
# {'__header__': b'Data produced by SWAN version 41.10; project: NFWF 65760; run number: 090', '__version__': '1.0', '__globals__': [], 'Hsig': array([[12.724424, 12.725627, 12.726647, ...,       nan,       nan,
#               nan],
#        [12.724424, 12.727441, 12.729597, ...,       nan,       nan,
#               nan],
#        [12.724424, 12.727952, 12.730808, ...,       nan,       nan,
#               nan],
#        ...,
#        [12.727033, 12.731134, 12.73461 , ...,       nan,       nan,
#               nan],
#        [12.727035, 12.730897, 12.734028, ...,       nan,       nan,
#               nan],
#        [12.727033, 12.729849, 12.73224 , ...,       nan,       nan,
#               nan]], dtype=float32), 'Setup': array([[-0.00115088, -0.00115232, -0.00115415, ...,         nan,
#                 nan,         nan],
#        [-0.00115041, -0.00115241, -0.00115449, ...,         nan,
#                 nan,         nan],
# ...

# %%
url_degraded = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\1perc_degraded_outs.mat'
url_degraded = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\65760_CoralReefs_Guam\Swan_Modeling\SwanRuns\NorthGrid\Degraded_Reef\1perc\1perc_DegradedReef_outs.mat'

matfile= loadmat(url_degraded)
    
print(matfile)
xp_Guam=matfile["Xp"]
yp_Guam=matfile["Yp"]
Hs_degraded_Guam=matfile["Hsig"]
Setup_degraded_Guam=matfile["Setup"]
# Out:
# {'__header__': b'Data produced by SWAN version 41.10; project: NFWF 65760; run number: 090', '__version__': '1.0', '__globals__': [], 'Hsig': array([[12.724424 , 12.725627 , 12.726647 , ...,        nan,        nan,
#                nan],
#        [12.724424 , 12.72744  , 12.729596 , ...,        nan,        nan,
#                nan],
#        [12.724424 , 12.727951 , 12.730808 , ...,        nan,        nan,
#                nan],
#        ...,
#        [12.727037 , 12.731139 , 12.734615 , ...,        nan,        nan,
#                nan],
#        [12.727039 , 12.730904 , 12.734032 , ...,        nan,        nan,
#                nan],
#        [12.727037 , 12.729854 , 12.7322445, ...,        nan,        nan,
#                nan]], dtype=float32), 'Setup': array([[-0.00109123, -0.00109266, -0.00109449, ...,         nan,
#                 nan,         nan],
#        [-0.00109075, -0.00109276, -0.00109484, ...,         nan,
#                 nan,         nan],
# ...

# %%
plt.figure(figsize=(10,6))
diff = Hs_restored_Guam - Hs_degraded_Guam
C = plt.pcolor(xp, yp, diff, cmap='viridis',vmin=-1, vmax=1)
cbar = plt.colorbar(C)
plt.title('Difference bet. Hs restored - degraded (meters)')
plt.savefig("Hs_Guam.png")
#plt.savefig('10perc_RestoredReef_Hs_GM_TSKtriadsoff.png')
print(np.nanmax(diff))
print(np.nanmin(diff))
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\508757199.py:2: RuntimeWarning: invalid value encountered in subtract
#   diff = Hs_restored_Guam - Hs_degraded_Guam
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\508757199.py:4: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar(C)
# 1.5156627
# -3.691312

# %%
print(yp_Guam[500,50])
print(xp_Guam[500,50])
# Out:
# 1496488.2
# 251944.47

# %%
plt.figure(figsize=(10,6))

diff = Setup_restored_Guam- Setup_degraded_Guam 
C = plt.pcolor(xp, yp, diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
cbar = plt.colorbar(C)
plt.title('Difference bet. Setup restored - degraded (meters)')
plt.savefig("Setup_Guam.png")

#plt.savefig('10perc_RestoredReef_Hs_GM_TSKtriadsoff.png')
print(np.nanmin(diff))
print(np.nanmax(diff))
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1323923119.py:3: RuntimeWarning: invalid value encountered in subtract
#   diff = Setup_restored_Guam- Setup_degraded_Guam
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1323923119.py:5: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar(C)
# -0.13673115
# 0.25892508

# %%
url_restored = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\1perc_restored_outs.mat'
#url_restored = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\65760_CoralReefs_Guam\Swan_Modeling\SwanRuns\NorthGrid\Restored_Reef\1perc\1perc_RestoredReef_outs.mat'
matfile= loadmat(url_restored)
    
print(matfile)
xp=matfile["Xp"]
yp=matfile["Yp"]
Hs_restored_St_croix=matfile["Hsig"]
Setup_restored_St_croix=matfile["Setup"]
Wlen_restored_St_croix = matfile["Wlen"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\dissip.mat')
Dissip_restored_St_croix  = matfile["Dissip"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\disbot.mat')
Disbot_restored_St_croix = matfile["Sfric"]

#matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\disswell.mat')
#Disswell_restored_St_croix = matfile["Swell"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\dissurf.mat')
Dissurf_restored_St_croix = matfile["Ssurf"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\diswcap.mat')
Diswcap_restored_St_croix = matfile["Swcap"]

matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Restored_Reef\1perc\tm01.mat')
tm_restored_St_croix  = matfile["Tm01"]

url_degraded = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\1perc_degraded_outs.mat'
#url_degraded = r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\65760_CoralReefs_Guam\Swan_Modeling\SwanRuns\NorthGrid\Degraded_Reef\1perc\1perc_DegradedReef_outs.mat'

matfile= loadmat(url_degraded)
    
print(matfile)
xp=matfile["Xp"]
yp=matfile["Yp"]
Hs_degraded_St_croix=matfile["Hsig"]
Setup_degraded_St_croix=matfile["Setup"]
Wlen_degraded_St_croix = matfile["Wlen"]

matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\dissip.mat')
Dissip_degraded_St_croix  = matfile["Dissip"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\disbot.mat')
Disbot_degraded_St_croix = matfile["Sfric"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\tm01.mat')
tm_degraded_St_croix  = matfile["Tm01"]

#matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\disswell.mat')
#Disswell_degraded_St_croix = matfile["Sswell"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\dissurf.mat')
Dissurf_degraded_St_croix = matfile["Ssurf"]
matfile = loadmat(r'C:\Users\tkalra\Desktop\NFWP_Swan_coral_USVirgin\69532_Coral_Reefs_St_Croix\Swan_Runs\Degraded_Reef\1perc\diswcap.mat')
Diswcap_degraded_St_croix = matfile["Swcap"]
# Out:
# {'__header__': b'Data produced by SWAN version 41.10; project: NFWF 69532; run number: 090', '__version__': '1.0', '__globals__': [], 'Hsig': array([[0.9635804 , 0.41059464, 0.37778535, ..., 1.6277376 , 1.9842192 ,
#         2.8556437 ],
#        [0.68476665, 0.50879836, 0.39062563, ..., 1.2289965 , 1.2252386 ,
#         1.2186841 ],
#        [0.68484443, 0.51279813, 0.39720017, ..., 1.2297009 , 1.2273031 ,
#         1.2216861 ],
#        ...,
#        [3.6839733 , 3.6780062 , 3.6767507 , ..., 3.440034  , 3.1971369 ,
#         2.6466033 ],
#        [3.6752188 , 3.6758597 , 3.6761034 , ..., 3.5498338 , 3.3698587 ,
#         2.6278086 ],
#        [3.6652117 , 3.6651964 , 3.6651723 , ..., 3.6758168 , 3.67594   ,
#         3.6760259 ]], dtype=float32), 'Setup': array([[ 0.3427152 ,  0.36151108,  0.36588308, ...,  0.09925054,
#          0.09027625,  0.0745139 ],
#        [ 0.3525847 ,  0.35709155,  0.36271816, ...,  0.10502028,
#          0.10493121,  0.11032306],
# ...

# %%
plt.figure(figsize=(10,6))
diff = Hs_restored_St_croix - Hs_degraded_St_croix
C = plt.pcolor(xp, yp, diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
cbar = plt.colorbar(C)
plt.title('Difference bet. Hs restored - degraded (meters)')
plt.savefig('1perc_Restored_Degraded_Hs.png')
print(np.nanmax(diff))
print(np.nanmin(diff))
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\171460053.py:2: RuntimeWarning: invalid value encountered in subtract
#   diff = Hs_restored_St_croix - Hs_degraded_St_croix
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\171460053.py:4: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar(C)
# 0.23475468
# -0.5820997

# %%
plt.figure(figsize=(10,6))

diff = Setup_restored_St_croix- Setup_degraded_St_croix
C = plt.pcolor(xp, yp, diff, cmap='viridis')#, vmin = -0.1, vmax = 0.1)
cbar = plt.colorbar(C)
plt.title('Difference bet. Setup restored - degraded (meters)')
#plt.savefig('1perc_Restored_Degraded_setup.png')
print(np.nanmin(diff))
print(np.nanmax(diff))
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1142727384.py:3: RuntimeWarning: invalid value encountered in subtract
#   diff = Setup_restored_St_croix- Setup_degraded_St_croix
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1142727384.py:5: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   cbar = plt.colorbar(C)
# -0.036411643
# 0.055027425

# %%
print(np.shape(yp))
# Out:
# (278, 483)

# %%
plt.figure(figsize=(10,6))
ii = 125
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 125], Setup_restored_St_croix[:, 125], label='Restored')
plt.plot(yp[:, 125], Setup_degraded_St_croix[:, 125], label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("setup in cross shore (m)")
#plt.savefig('Setup_cross-shore.png')
# Out:
# C:\Users\tkalra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\cbook.py:1398: RuntimeWarning: invalid value encountered in cast
#   return np.asarray(x, float)
# Text(0.5, 1.0, 'setup in cross shore (m)')

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Hs_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:, 100], Hs_degraded_St_croix[:, 100], label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Hs in cross shore (m)")
#plt.ylim(1.5, 2.5)
plt.savefig('Hs_cross-shore.png')

#cbar = plt.colorbar(C)

# %%
plt.figure(figsize=(10,6))
#diff=Dissip_restored_St_croix[:, 100]-Dissip_degraded_St_croix[:, 100]
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Dissip_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:,100], Dissip_degraded_St_croix[: , 100], label='Degraded')

#plt.plot(diff)#, label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Dissipation in Watts per sq meter")
plt.savefig("total_dissipation")
#plt.ylim(0, )
#plt.savefig('Wlen_cross-shore.png')

# %%
plt.figure(figsize=(10,6))
#diff=Dissip_restored_St_croix[:, 100]-Dissip_degraded_St_croix[:, 100]
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], tm_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:,100], tm_degraded_St_croix[: , 100], label='Degraded')

#plt.plot(diff)#, label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Tm01")
plt.savefig('period_mean_cross-shore.png')
#plt.ylim(0, )
#plt.savefig('Wlen_cross-shore.png')

# %%
plt.figure(figsize=(10,6))
#diff=Dissip_restored_St_croix[:, 100]-Dissip_degraded_St_croix[:, 100]
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.pcolor(xp, yp, tm_restored_St_croix-tm_degraded_St_croix, label='Restored')
#plt.plot(yp[:,100], tm_degraded_St_croix[: , 100], label='Degraded')

#plt.plot(diff)#, label='Degraded')
#plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
#plt.title("Tm01")
plt.colorbar()
plt.savefig('pcolor_period_mean.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\4282602796.py:4: RuntimeWarning: invalid value encountered in subtract
#   plt.pcolor(xp, yp, tm_restored_St_croix-tm_degraded_St_croix, label='Restored')
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\4282602796.py:10: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Calculated wave setup 
Hs = Hs_restored_St_croix[:, 100]
T = tm_restored_St_croix[:,100]
L = Wlen_restored_St_croix[:, 100]

Calc_restored_setup= (Hs*Hs*T)/(16.0*L)

# Calculated wave setup 
Hs = Hs_degraded_St_croix[:, 100]
T = tm_degraded_St_croix[:,100]
L = Wlen_degraded_St_croix[:, 100]

Calc_degraded_setup= (Hs*Hs*T)/(16.0*L)

plt.figure(figsize=(10,6))
#diff=Dissip_restored_St_croix[:, 100]-Dissip_degraded_St_croix[:, 100]
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Calc_restored_setup, label='Restored')
plt.plot(yp[:,100], Calc_degraded_setup, label='Degraded')

#plt.plot(diff)#, label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title('calculated setup')
plt.savefig('calculated_setup_cross-shore.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\296903445.py:6: RuntimeWarning: invalid value encountered in multiply
#   Calc_restored_setup= (Hs*Hs*T)/(16.0*L)
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\296903445.py:13: RuntimeWarning: invalid value encountered in multiply
#   Calc_degraded_setup= (Hs*Hs*T)/(16.0*L)

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Disbot_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:, 100], Disbot_degraded_St_croix[:, 100], label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Dissipation at the bottom in Watts per sq meter")
#plt.ylim(0, 150)
plt.savefig('bottom_dissipation_cross-shore.png')

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.pcolor(xp, yp, Disbot_restored_St_croix - Disbot_degraded_St_croix, label='Restored', vmin = -0.001, vmax= 0.001)
plt.colorbar()

plt.title("Total bottom friction dissipation")
plt.savefig('total_pcolor_dissip_bottom.png')
#plt.plot(yp[:, 100], Disbot_degraded_St_croix, label='Degraded')
#plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
#plt.title("Dissipation at the bottom in Watts per sq meter")
#plt.ylim(0, 150)
#plt.savefig('bottom_dissipation_cross-shore.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1710480368.py:4: RuntimeWarning: invalid value encountered in subtract
#   plt.pcolor(xp, yp, Disbot_restored_St_croix - Disbot_degraded_St_croix, label='Restored', vmin = -0.001, vmax= 0.001)
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1710480368.py:5: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.pcolor(xp, yp, Diswcap_restored_St_croix - Diswcap_degraded_St_croix, label='Restored', vmin = -0.0001, vmax= 0.0001)
plt.colorbar()
#plt.plot(yp[:, 100], Disbot_degraded_St_croix, label='Degraded')
#plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
#plt.title("Dissipation at the bottom in Watts per sq meter")
#plt.ylim(0, 150)
#plt.savefig('bottom_dissipation_cross-shore.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1001513580.py:4: RuntimeWarning: invalid value encountered in subtract
#   plt.pcolor(xp, yp, Diswcap_restored_St_croix - Diswcap_degraded_St_croix, label='Restored', vmin = -0.0001, vmax= 0.0001)
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\1001513580.py:5: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.pcolor(xp, yp, Dissip_restored_St_croix - Dissip_degraded_St_croix, label='Restored', vmin = -0.001, vmax= 0.001)
plt.colorbar()
plt.title("Total dissipation")
plt.savefig('total_pcolor_dissip.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\2769582741.py:4: RuntimeWarning: invalid value encountered in subtract
#   plt.pcolor(xp, yp, Dissip_restored_St_croix - Dissip_degraded_St_croix, label='Restored', vmin = -0.001, vmax= 0.001)
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\2769582741.py:5: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Diswcap_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:, 100], Diswcap_degraded_St_croix[:, 100], label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Dissipation due to white capping in Watts per sq meter")
#plt.ylim(0, 150)
plt.savefig('whitecap_dissip_cross-shore.png')

# %%
plt.figure(figsize=(10,6))

#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp[:, 100], Dissurf_restored_St_croix[:, 100], label='Restored')
plt.plot(yp[:, 100], Dissurf_degraded_St_croix[:, 100], label='Degraded')
plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
plt.title("Dissipation due to surf breaking in Watts per sq meter")
#plt.ylim(0, 150)
plt.savefig('ssurf_dissip_cross-shore.png')

# %%
plt.figure(figsize=(10,6))
#diff=Dissip_restored_St_croix[:, 100]-Dissip_degraded_St_croix[:, 100]
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.pcolor(xp, yp, Wlen_restored_St_croix-Wlen_degraded_St_croix, label='Restored')
#plt.plot(yp[:,100], tm_degraded_St_croix[: , 100], label='Degraded')
plt.colorbar()
#plt.plot(diff)#, label='Degraded')
#plt.legend() # diff, cmap='viridis', vmin = -0.1, vmax = 0.1)
#plt.title("Tm01")
plt.savefig('pcolor_wavelength.png')
# Out:
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\367227266.py:4: RuntimeWarning: invalid value encountered in subtract
#   plt.pcolor(xp, yp, Wlen_restored_St_croix-Wlen_degraded_St_croix, label='Restored')
# C:\Users\tkalra\AppData\Local\Temp\ipykernel_6364\367227266.py:6: MatplotlibDeprecationWarning: Getting the array from a PolyQuadMesh will return the full array in the future (uncompressed). To get this behavior now set the PolyQuadMesh with a 2D array .set_array(data2d).
#   plt.colorbar()

# %%
plt.figure(figsize=(10,6))
ii = 250
#diff = Setup_restored_St_croix- Setup_degraded_St_croix
plt.plot(yp_Guam[:, ii], Setup_restored_Guam[:, ii], label='Restored')
plt.plot(yp_Guam[:, ii], Setup_degraded_Guam[:, ii], label='Degraded')

# %%
print(yp[50,50])
# Out:
# 192879.81
